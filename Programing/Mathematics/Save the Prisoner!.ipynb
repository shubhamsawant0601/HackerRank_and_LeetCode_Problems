# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def saveThePrisoner(n, m, s):
    return (m-1+s)%n or n

# %%
saveThePrisoner(352926151, 380324688, 94730870)
# Out:
# 122129406

# %%
# (m-1+s)%n 
# n is used as when % gives 0 it will return n

# %%
a = [1,2,3,4,5,6,7,8,9]
a[-4:-1]
# Out:
# [6, 7, 8]

# %%
x=[1,2,3,4]
for i in x:
    print(i)
    continue
# Out:
# 1
# 2
# 3
# 4

# %%
a =["34","\"12\"", "23"]
a.sort()
a
# Out:
# ['"12"', '23', '34']

# %%
bool(" ")
# Out:
# True

# %%
class Leave:
    def __init__(self, id1, type1, days1, date1 ):
        self.id1  = id1
        self.type1 = type1
        self.days1 = days1
        self.date1 = date1
        
        
class Employee
    def __init__(self, llist1, lbal1):
        self.llist1 = llist1
        self.lbal1 = lbal1
        
        
    def getUpdated():
        
        
    def getLeave(self,m1, m2):
        count = 0
        
        for i in self.llist1:
            if m1 =< int(i.date[3:5])<=m2:
                count+=1
                
        return count
        
        
        
        

n1 = int(input())
llist1 = []
for i in range(n1):
    id1 = int(input())
    type1 = input()
    days1 = int(input())
    date1 = input()
    
    llist1.append(Leave(id1, type1, days1, date1))
    
    
n2 = int(input())
arr =[]
lbal1 = {}
for i in range(n2):
    arr.append(int(input()))
    
lbal1["EL"] = arr[0]
lbal1["CL"] = arr[1]
lbal1["SL"] = arr[2]

m1 = int(input())
m2 = int(input())

obj1 = Employee(llist1, lbal1)

a = obj1
# Out:
#   File "C:\Users\Shubham\AppData\Local\Temp/ipykernel_14992/2296675130.py", line 9
#     class Employee
#                   ^
# SyntaxError: invalid syntax

# %%
class Leave:
    def __init__(self, id1, type1, days1, date1 ):
        self.id1  = id1
        self.type1 = type1
        self.days1 = days1
        self.date1 = date1
        
        
class Employee:
    def __init__(self, llist1, lbal1):
        self.llist1 = llist1
        self.lbal1 = lbal1
        
        
    def getUpdated(self):
        dic = self.lbal1
        flag = "True"
        print(dic)
        for i in self.llist1:
            
            dic[i.type1] = dic[i.type1] - i.days1
            if dic[i.type1]<=0:
                print(i.type1,dic[i.type1])
                flag = "Insufficient balance for CL applied on {}".format(i.date1)
            
        
        dic = dict(sorted(dic.items(), key=lambda x:x[1], reverse=False)) 
        return dic, flag
        
    def getLeave(self,m1, m2):
        count = 0
        for i in self.llist1:
            if m1 <= int(i.date1[3:5])<= m2:
                count+=1

        return count

# %%
obj1 = Employee(l, lbal1)
    
obj1.getLeave(m1, m2)
ans , flag= obj1.getUpdated()

for k, v in ans.items():
    print("{}:{}".format(k,v))
    
    
ans1 = obj1.getLeave(m1, m2)

if ans1==0:
    print("No leave applied between given months")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14992/6584551.py in <module>
# ----> 1 obj1 = Employee(l, lbal1)
#       2
#       3 obj1.getLeave(m1, m2)
#       4 ans , flag= obj1.getUpdated()
#       5
#
# NameError: name 'lbal1' is not defined

# %%
n1 = int(input())
llist1 = []
for i in range(n1):
    id1 = int(input())
    type1 = input()
    days1 = int(input())
    date1 = input()
    
    llist1.append(Leave(id1, type1, days1, date1))
    
    

lbal1 = {}
    
lbal1["EL"] = int(input())
lbal1["CL"] =  int(input())
lbal1["SL"] =  int(input())

m1 = int(input())
m2 = int(input())

# %%
a = Leave(1011, "CL", 1, "12-02-21")
b = Leave(1012, "CL", 2, "13-04-21")
c = Leave(1013, "EL", 3, "13-08-21")
d = Leave(1014, "EL", 2, "23-11-21")
e = Leave(1015, "SL", 1, "24-12-21")

m1 = 4
m2 = 8

Ibal1 = {"EL": 20, "CL":4 , "SL":31}

l = [a,b,c,d,e]
