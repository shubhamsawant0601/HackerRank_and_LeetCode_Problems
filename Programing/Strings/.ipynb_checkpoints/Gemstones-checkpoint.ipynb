# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def gemstones(arr):
    arr = [set(list(i)) for i in arr]
    final = set(arr[0])
 
    for i in arr:
        final = final.intersection(i)
    
    return len(final)
